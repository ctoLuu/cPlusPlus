# %%
import pandas as pd
use_cols = [i for i in range(4)]
df = pd.read_excel('.\附件1.xlsx', sheet_name=1)
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        编号  速度(km/h)  电量消耗速率(kW·h/km)  初始站点 无人车配送范围（路段） Unnamed: 5 Unnamed: 6  \
# 0    无人车1      15.7            0.050    16         1,2        2,3        3,4
# 1    无人车2      21.9            0.050    34         2,3        3,4        3,6
# 2    无人车3      17.1            0.049    13         3,4        3,6        4,5
# 3    无人车4      16.5            0.058    13         6,7        7,8        8,9
# 4    无人车5      20.1            0.051    24         8,9       9,14      14,17
# 5    无人车6      18.2            0.071    24       14,17      17,25      17,21
# 6    无人车7      23.2            0.072    30       17,25      25,30      30,35
# 7    无人车8      20.2            0.044    61       35,43      43,44      44,45
# 8    无人车9      23.8            0.063    56       43,44      44,45      45,46
# 9   无人车10      21.8            0.069    51       44,45      45,46      46,47
# 10  无人车11      24.3            0.056    45       45,46      46,47      47,52
# ...

# %%
df.set_index(['编号'])
df.index += 1

# %%
df.drop(columns=['编号'])
# Out:
#     速度(km/h)  电量消耗速率(kW·h/km)  初始站点 无人车配送范围（路段） Unnamed: 5 Unnamed: 6  \
# 1       15.7            0.050    16         1,2        2,3        3,4
# 2       21.9            0.050    34         2,3        3,4        3,6
# 3       17.1            0.049    13         3,4        3,6        4,5
# 4       16.5            0.058    13         6,7        7,8        8,9
# 5       20.1            0.051    24         8,9       9,14      14,17
# 6       18.2            0.071    24       14,17      17,25      17,21
# 7       23.2            0.072    30       17,25      25,30      30,35
# 8       20.2            0.044    61       35,43      43,44      44,45
# 9       23.8            0.063    56       43,44      44,45      45,46
# 10      21.8            0.069    51       44,45      45,46      46,47
# 11      24.3            0.056    45       45,46      46,47      47,52
# 12      17.4            0.059    82       57,62      62,63      63,66
# ...

# %%
road = pd.read_excel('.\附件1.xlsx')
road
# Out:
#     Unnamed: 0  站点1  站点2  站点3  站点4  站点5  站点6  站点7  站点8  站点9  ...  站点113  \
# 0          站点1  NaN  8.4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 1          站点2  8.4  NaN  4.5  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 2          站点3  NaN  4.5  NaN  5.3  NaN  1.6  NaN  NaN  NaN  ...    NaN
# 3          站点4  NaN  NaN  5.3  NaN  5.1  NaN  NaN  NaN  NaN  ...    NaN
# 4          站点5  NaN  NaN  NaN  5.1  NaN  NaN  NaN  NaN  NaN  ...    NaN
# ..         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...    ...
# 117      站点118  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 118      站点119  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 119      站点120  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 120      站点121  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
# 121      站点122  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN
#
#      站点114  站点115  站点116  站点117  站点118  站点119  站点120  站点121  站点122
# ...

# %%
lists = [[] for _ in range(40)]
i = 0
for index, row in df.iterrows():
    for col in range(4, len(df.columns)):
        if not pd.isna(row.iloc[col]):
            lists[2 * i].append(int(row.iloc[col].split(',')[0]))
            lists[2 * i + 1].append(int(row.iloc[col].split(',')[1]))
    i += 1
for j in range(len(lists)):
    print(lists[j])
# Out:
# [1, 2, 3, 3, 4, 6, 7, 8, 9, 9, 9, 11, 11, 14, 14, 15, 17, 17, 17, 18, 18, 21, 21, 23, 25, 25, 27, 27]
# [2, 3, 4, 6, 5, 7, 8, 9, 14, 11, 10, 13, 12, 15, 17, 16, 21, 18, 25, 20, 19, 22, 23, 24, 26, 27, 28, 29]
# [2, 3, 3, 4, 6, 7, 8, 9, 9, 9, 11, 11, 14, 14, 15, 17, 17, 17, 18, 18, 21, 21, 23, 25, 25, 25, 27, 27, 30, 31, 31, 33]
# [3, 4, 6, 5, 7, 8, 9, 14, 11, 10, 13, 12, 15, 17, 16, 21, 18, 25, 20, 19, 22, 23, 24, 26, 27, 30, 28, 29, 31, 32, 33, 34]
# [3, 3, 4, 6, 7, 8, 9, 9, 9, 11, 11, 14, 14, 15, 17, 17, 17, 18, 18, 21, 21, 23, 25, 25, 25, 27, 27, 30, 30, 31, 31, 33, 35, 35, 36, 36, 39, 39, 41]
# [4, 6, 5, 7, 8, 9, 14, 11, 10, 13, 12, 15, 17, 16, 21, 18, 25, 20, 19, 22, 23, 24, 26, 27, 30, 28, 29, 35, 31, 32, 33, 34, 36, 39, 37, 38, 41, 40, 42]
# [6, 7, 8, 9, 9, 11, 11]
# [7, 8, 9, 10, 11, 13, 12]
# [8, 9, 14, 17, 17, 17, 18, 18, 21, 21, 23, 25, 30, 35, 43, 44, 45]
# [9, 14, 17, 25, 21, 18, 20, 19, 22, 23, 24, 30, 35, 43, 44, 45, 46]
# [14, 17, 17, 17, 18, 18, 21, 21, 23, 25, 30]
# ...

# %%
position = 122
for i in range(20):
    for j in lists[2 * i + 1]:
        if j == position:
            for k in
# Out:
# 2
# 3
# 4
# 6
# 5
# 7
# 8
# 9
# 14
# 11
# 10
# 13
# 12
# 15
# 17
# 16
# 21
# 18
# 25
# 20
# 19
# 22
# 23
# 24
# 26
# 27
# 28
# 29
# 3
# 4
# 6
# 5
# 7
# 8
# 9
# 14
# 11
# 10
# 13
# 12
# 15
# 17
# 16
# 21
# 18
# 25
# 20
# 19
# 22
# 23
# 24
# 26
# 27
# 30
# 28
# 29
# 31
# 32
# 33
# 34
# 4
# 6
# 5
# 7
# 8
# 9
# 14
# 11
# 10
# 13
# 12
# 15
# 17
# 16
# 21
# 18
# 25
# 20
# 19
# 22
# 23
# 24
# 26
# 27
# 30
# 28
# 29
# 35
# 31
# 32
# 33
# 34
# 36
# 39
# 37
# 38
# 41
# 40
# 42
# 7
# 8
# 9
# 10
# 11
# 13
# 12
# 9
# 14
# 17
# 25
# 21
# 18
# 20
# 19
# 22
# 23
# 24
# 30
# 35
# 43
# 44
# 45
# 46
# 17
# 25
# 21
# 18
# 20
# 19
# 22
# 23
# 24
# 30
# 35
# 25
# 30
# 35
# 43
# 44
# 45
# 46
# 47
# 52
# 57
# 62
# 43
# 44
# 45
# 46
# 47
# 52
# 57
# 58
# 59
# 60
# 61
# 44
# 45
# 46
# 47
# 52
# 53
# 54
# 55
# 56
# 45
# 46
# 47
# 48
# 50
# 49
# 51
# 46
# 47
# 52
# 62
# 63
# 66
# 74
# 75
# 76
# 77
# 78
# 83
# 79
# 81
# 80
# 82
# 84
# 85
# 62
# 63
# 66
# 74
# 70
# 67
# 68
# 69
# 71
# 72
# 73
# 75
# 76
# 77
# 78
# ...

# %%
def
