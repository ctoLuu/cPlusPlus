# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
people = {
    "first": ["Corey", "Jane", "John"],
    "last": ["Schafer", 'Doe', 'Doe'],
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe&gmail.com', 'JohnDoe@email.com']
}

# %%
df.info()
pl = pd.DataFrame(people)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.iloc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df.loc[0:2, 'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %%
pl
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe&gmail.com
# 2   John      Doe        JohnDoe@email.com

# %%
pl.set_index('email', inplace=True)
pl
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe&gmail.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
pl.index
pl.loc['CoreyMSchafer@gmail.com', 'last']
# Out:
# 'Schafer'

# %%
pl.reset_index(inplace=True)
pl
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe&gmail.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
schema_df.sort_index(inplace=True, ascending=False)

# %%
filt = (pl['last'] == 'Doe') & (pl['first'] == 'John')

# %%
pl.loc[filt, 'email']
pl.loc[~filt, 'email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe&gmail.com
# Name: email, dtype: object

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary, ['LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                                       LanguageWorkedWith  ConvertedComp
# 5                                             Java;R;SQL       366420.0
# 8      Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...        95179.0
# 12     Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...        90000.0
# 15     Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...       455352.0
# 21     Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...       103000.0
# ...                                                  ...            ...
# 88323  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...       180000.0
# 88324  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...      2000000.0
# 88325               HTML/CSS;JavaScript;Scala;TypeScript       130000.0
# 88326                   Bash/Shell/PowerShell;C++;Python        82488.0
# 88329             C#;HTML/CSS;Java;JavaScript;PHP;Python       588012.0
#
# [22289 rows x 2 columns]

# %%
countries = ['United States', 'India', 'Germany']
filt = df['Country'].isin(countries)
df.loc[filt, 'Country']
# Out:
# 3        United States
# 7                India
# 9                India
# 12       United States
# 13             Germany
#              ...
# 88852            India
# 88853            India
# 88859    United States
# 88864            India
# 88877    United States
# Name: Country, Length: 35876, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
df.loc[filt, 'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
cols = ['first', 'last', 'email']
pl = pl.reindex(columns=cols)
pl
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe&gmail.com
# 2   John      Doe        JohnDoe@email.com

# %%
pl.columns = ['first_name', 'last_name', 'email']
pl.columns = [x.upper() for x in pl.columns]
pl.columns = pl.columns.str.replace('_', ' ')
pl.rename(columns={'FIRST NAME': 'first', 'LAST NAME':'last'})
pl
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe&gmail.com
# 2       John       Doe        JohnDoe@email.com

# %%
pl.loc[2] = ['John', 'Smith', 'JognSmith@email.com']
pl
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe&gmail.com
# 2       John     Smith      JognSmith@email.com

# %%
filt = (pl['EMAIL'] == 'JaneDoe&gmailcom')
pl.loc[filt, 'LAST NAME'] = 'Smith'

# %%
pl
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe&gmail.com
# 2       John     Smith      JognSmith@email.com

# %%
pl['EMAIL'] = pl['EMAIL'].str.lower()

# %%
pl
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  coreymschafer@gmail.com
# 1       Jane       Doe        janedoe&gmail.com
# 2       John     Smith      jognsmith@email.com

# %%
pl['EMAIL'] = pl['EMAIL'].apply(lambda x: x.lower())

# %%
pl
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  coreymschafer@gmail.com
# 1       Jane       Doe        janedoe&gmail.com
# 2       John     Smith      jognsmith@email.com

# %%
pl.apply(len)
# Out:
# FIRST NAME    3
# LAST NAME     3
# EMAIL         3
# dtype: int64

# %%
pl.apply(pd.Series.min)
# Out:
# FIRST NAME                      Corey
# LAST NAME                         Doe
# EMAIL         coreymschafer@gmail.com
# dtype: object

# %%
pl.applymap(len)
pl.applymap(str.lower)
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      corey   schafer  coreymschafer@gmail.com
# 1       jane       doe        janedoe&gmail.com
# 2       john     smith      jognsmith@email.com

# %%
pl
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  coreymschafer@gmail.com
# 1       Jane       Doe        janedoe&gmail.com
# 2       John     Smith      jognsmith@email.com

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'})
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True, 'No':False})

# %%
df
# Out:
#        Respondent                                         MainBranch  \
# 0               1             I am a student who is learning to code
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 88878       88377                                                NaN
# 88879       88601                                                NaN
# 88880       88802                                                NaN
# 88881       88816                                                NaN
# 88882       88863                                                NaN
#
#        Hobbyist                                        OpenSourcer  \
# 0          True                                              Never
# ...

# %%
pl['FULL NAME'] = pl['FIRST NAME'] + ' ' + pl['LAST NAME']
pl
# Out:
#   FIRST NAME LAST NAME                    EMAIL      FULL NAME
# 0      Corey   Schafer  coreymschafer@gmail.com  Corey Schafer
# 1       Jane       Doe        janedoe&gmail.com       Jane Doe
# 2       John     Smith      jognsmith@email.com     John Smith

# %%
pl.drop(columns=['FIRST NAME', 'LAST NAME'], inplace=True)
pl[['first', 'last']] = pl['FULL NAME'].str.split(' ', expand=True)

# %%
pl.loc[1, 'EMAIL'] = 'janedoe@gmail.com'
pl.loc[2, 'EMAIL'] = 'johnsmith@gmail.com'
pl
# Out:
#                      EMAIL      FULL NAME  first     last
# 0  coreymschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        janedoe@gmail.com       Jane Doe   Jane      Doe
# 2      johnsmith@gmail.com     John Smith   John    Smith

# %%
pl = pl._append({'first': 'Tony'}, ignore_index=True)

# %%
pl.drop(index=3, inplace=True)

# %%
pl
# Out:
#                      EMAIL      FULL NAME  first     last
# 0  coreymschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        janedoe@gmail.com       Jane Doe   Jane      Doe
# 2      johnsmith@gmail.com     John Smith   John    Smith

# %%
filt = (pl['last'] == 'Doe')
pl.loc[filt]
pl.drop(index=pl[filt].index)
# Out:
#                      EMAIL      FULL NAME  first     last
# 0  coreymschafer@gmail.com  Corey Schafer  Corey  Schafer
# 2      johnsmith@gmail.com     John Smith   John    Smith

# %%
pl.sort_values(by=['last', 'first'], ascending=[False, True])
# Out:
#                      EMAIL      FULL NAME  first     last
# 2      johnsmith@gmail.com     John Smith   John    Smith
# 0  coreymschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        janedoe@gmail.com       Jane Doe   Jane      Doe

# %%
pl.sort_index()
# Out:
#                      EMAIL      FULL NAME  first     last
# 0  coreymschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        janedoe@gmail.com       Jane Doe   Jane      Doe
# 2      johnsmith@gmail.com     John Smith   John    Smith

# %%
pl['last'].sort_values()
# Out:
# 1        Doe
# 0    Schafer
# 2      Smith
# Name: last, dtype: object

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# 57      2000000.0
# 101     2000000.0
# 164     2000000.0
# 434     2000000.0
# 450     2000000.0
# 489     2000000.0
# 537     2000000.0
# 767     2000000.0
# 786     2000000.0
# 1228    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')
df.nsmallest(10, 'ConvertedComp')
# Out:
#       Respondent                      MainBranch  Hobbyist  \
# 278          280  I am a developer by profession      True
# 291          293  I am a developer by profession      True
# 719          722  I am a developer by profession     False
# 1101        1105  I am a developer by profession     False
# 1494        1501  I am a developer by profession      True
# 1678        1685  I am a developer by profession      True
# 1774        1782  I am a developer by profession      True
# 2011        2019  I am a developer by profession     False
# 2087        2095  I am a developer by profession      True
# 2656        2665  I am a developer by profession      True
#
#                                             OpenSourcer  \
# 278                             Less than once per year
# 291                             Less than once per year
# 719   Less than once a month but more than once per ...
# 1101                                              Never
# ...

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df['ConvertedComp'].describe()
# Out:
# count    5.582300e+04
# mean     1.271107e+05
# std      2.841523e+05
# min      0.000000e+00
# 25%      2.577750e+04
# 50%      5.728700e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# True     71257
# False    17626
# Name: count, dtype: int64

# %%
df['Hobbyist'].value_counts(normalize=True)
# Out:
# Hobbyist
# True     0.801694
# False    0.198306
# Name: proportion, dtype: float64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#        Respondent                              MainBranch  Hobbyist  \
# 7               8             I code primarily as a hobby      True
# 9              10          I am a developer by profession      True
# 14             15  I am a student who is learning to code      True
# 49             50          I am a developer by profession      True
# 64             65          I am a developer by profession      True
# ...           ...                                     ...       ...
# 88808       77339                                     NaN      True
# 88825       79795                                     NaN      True
# 88852       83862                                     NaN      True
# 88853       84299                                     NaN      True
# 88864       86012                                     NaN      True
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt].value_counts()
# Out:
# Respondent  MainBranch                      Hobbyist  OpenSourcer                                         OpenSource                                                                       Employment          Country        Student  EdLevel                                                 UndergradMajor                                                        EduOther                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  OrgSize                   DevType                                                      
# ...

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               0.303571
# YouTube                     0.207418
# I don't use social media    0.106456
# Reddit                      0.096154
# Twitter                     0.089286
# Instagram                   0.064560
# WhatsApp                    0.061813
# Facebook                    0.046016
# LinkedIn                    0.024038
# Snapchat                    0.000687
# Name: proportion, dtype: float64

# %%
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Java').sum()
# Out:
# 7275

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
import numpy as np

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].describe()
# Out:
# count    87938.000000
# mean        11.662114
# std          9.152772
# min          0.000000
# 25%          5.000000
# 50%          9.000000
# 75%         15.000000
# max         51.000000
# Name: YearsCode, dtype: float64

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
india_df.to_csv('data/modified.csv')

# %%
india_df.to_csv('data/modified.tsv', sep='\t')
